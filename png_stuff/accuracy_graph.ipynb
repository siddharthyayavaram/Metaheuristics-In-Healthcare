# %%
import matplotlib.pyplot as plt
import numpy as np

# Replace this array with your accuracy values
accuracies = [
    0.6413571428571428, 0.7983571428571429, 0.7983571428571429,
    0.7983571428571429, 0.7983571428571429, 0.7983571428571429, 0.7983571428571429,
    0.7983571428571429, 0.7983571428571429, 0.7983571428571429, 0.7983571428571429,
    0.7983571428571429, 0.8077142857142857, 0.8077142857142857, 0.8077142857142857,
    0.8077142857142857, 0.8077142857142857, 0.8077142857142857, 0.8077142857142857,
    0.8077142857142857, 0.8077142857142857, 0.8077142857142857, 0.8077142857142857,
    0.8077142857142857, 0.8077142857142857, 0.8077142857142857, 0.8116428571428571,
    0.8116428571428571, 0.8116428571428571, 0.8116428571428571, 0.8116428571428571,
    0.8116428571428571, 0.8116428571428571, 0.8116428571428571, 0.8153571428571429,
    0.8153571428571429, 0.8153571428571429, 0.8157142857142857, 0.8157142857142857,
    0.8157142857142857, 0.8157142857142857, 0.8157142857142857, 0.8157142857142857,
    0.8157142857142857, 0.8157142857142857, 0.8157142857142857, 0.8157142857142857,
    0.8157142857142857, 0.8157142857142857, 0.8157142857142857, 0.8157142857142857,
    0.8157142857142857, 0.8157142857142857, 0.8157142857142857, 0.8157142857142857,
    0.8157142857142857, 0.8157142857142857, 0.8157142857142857, 0.8157142857142857,
    0.8157142857142857, 0.8157142857142857, 0.8157142857142857, 0.8157142857142857,
    0.8157142857142857, 0.8157142857142857, 0.8157142857142857, 0.8157142857142857,
    0.8157142857142857, 0.8157142857142857, 0.8157142857142857, 0.8157142857142857,
    0.8157142857142857, 0.8157142857142857, 0.8157142857142857, 0.8157142857142857,
    0.8157142857142857, 0.8157142857142857, 0.8157142857142857, 0.8157142857142857,
    0.8157142857142857, 0.8157142857142857, 0.8157142857142857, 0.8157142857142857,
    0.8157142857142857, 0.8157142857142857, 0.8157142857142857, 0.8157142857142857,
    0.8157142857142857, 0.8157142857142857, 0.8157142857142857, 0.8157142857142857,
    0.8157142857142857, 0.8157142857142857, 0.8157142857142857, 0.8157142857142857,
    0.8157142857142857, 0.8157142857142857, 0.8157142857142857, 0.8157142857142857,
    0.8157142857142857, 0.8157142857142857, 0.8157142857142857, 0.8157142857142857,
    0.8157142857142857, 0.8157142857142857, 0.8157142857142857, 0.8157142857142857,
    0.8157142857142857, 0.8157142857142857, 0.8157142857142857, 0.8157142857142857,
    0.8157142857142857, 0.8157142857142857, 0.8157142857142857, 0.8157142857142857,
    0.8157142857142857, 0.8157142857142857, 0.8157142857142857, 0.8157142857142857,
    0.8157142857142857, 0.8157142857142857, 0.8157142857142857, 0.8157142857142857,
    0.8157142857142857, 0.8338571428571429, 0.8338571428571429, 0.8338571428571429,
    0.8338571428571429, 0.8338571428571429, 0.8338571428571429, 0.8338571428571429,
    0.8338571428571429, 0.8338571428571429, 0.8338571428571429, 0.8338571428571429,
    0.8338571428571429, 0.8338571428571429, 0.8338571428571429, 0.8338571428571429,
    0.8338571428571429, 0.8338571428571429, 0.8338571428571429, 0.8338571428571429,
    0.8338571428571429, 0.8338571428571429, 0.8338571428571429, 0.8338571428571429,
    0.8338571428571429, 0.8338571428571429, 0.8338571428571429, 0.8338571428571429,
    0.8338571428571429, 0.8338571428571429, 0.8338571428571429, 0.8338571428571429,
    0.8338571428571429, 0.8338571428571429, 0.8338571428571429, 0.8338571428571429,
    0.8338571428571429, 0.8338571428571429, 0.8338571428571429, 0.8338571428571429,
    0.8338571428571429, 0.8338571428571429, 0.8338571428571429, 0.8338571428571429,
    0.8338571428571429, 0.8338571428571429, 0.8338571428571429, 0.8338571428571429,
    0.8338571428571429, 0.8338571428571429, 0.8338571428571429, 0.8338571428571429,
    0.8338571428571429, 0.8338571428571429, 0.8338571428571429, 0.8338571428571429,
    0.8338571428571429, 0.8338571428571429, 0.8338571428571429, 0.8338571428571429,
    0.8338571428571429, 0.8338571428571429, 0.8338571428571429, 0.8338571428571429,
    0.8338571428571429, 0.8338571428571429, 0.8338571428571429, 0.8338571428571429,
    0.8338571428571429, 0.8338571428571429, 0.8338571428571429, 0.8338571428571429,
    0.8338571428571429, 0.8338571428571429, 0.8338571428571429, 0.8338571428571429,
    0.8338571428571429, 0.8338571428571429, 0.8338571428571429, 0.8338571428571429
]

# %%
# Plotting the accuracies for each iteration
plt.figure(figsize=(10, 6))
plt.plot(np.arange(1, len(accuracies) + 1), accuracies, marker='.', linestyle='-', color='b')
plt.xlabel('Iterations')
plt.ylabel('Accuracy')
plt.title('Accuracies for Each Iteration')
plt.grid(True)
plt.show()
